# %%
rows = 5
for i in range(1,rows+1):
    print(" " * (rows -i) + "*"*(2 * i -1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
rows = 5
for i in range(rows,0,-1):
    print(" " * (rows -i) + "*" * (2 * i -1))
# Out:
# *********
#  *******
#   *****
#    ***
#     *

# %%
rows = 5
for i in range(1,rows+1):
    print(" " * (rows -i) + "*"*(2*i-1))
for i in range(rows,0,-1):
    print(" " * (rows - i) + "*"*(2*i -1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********
# *********
#  *******
#   *****
#    ***
#     *

# %%
rows = 5
for i in range(1,rows +1):
    print("*" * i +' '* 2*(rows -i) + "*" * i)
# Out:
# *        *
# **      **
# ***    ***
# ****  ****
# **********

# %%
rows = 5
for i in range(rows,0,-1):
    print("*" * i + " " * 2*(rows -i) + "*" * i)
# Out:
# **********
# ****  ****
# ***    ***
# **      **
# *        *

# %%
rows = 5
for i in range(1,rows+1):
    print("*" * i + " " * 2*(rows -i) + "*" * i)
for i in range(rows,0,-1):
    print("*" * i + " " * 2*(rows -i) + "*" * i)
# Out:
# *        *
# **      **
# ***    ***
# ****  ****
# **********
# **********
# ****  ****
# ***    ***
# **      **
# *        *

# %%
rows = 5
for i in range(1,rows +1):
    print("*" * i)
for i in range(rows,0,-1):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****
# *****
# ****
# ***
# **
# *

# %%
rows = 5
for i in range(rows):
    if i == 0 or i == rows -1:
        print("*" * rows)
    else:
        print("*" + " " * (rows -2) + "*")
# Out:
# *****
# *   *
# *   *
# *   *
# *****

# %%
rows = 5
for i in range(rows):
    if i == 0 or i == 1 or i == 2 or i == 4 or i == rows - 1:
        print("*" * rows)
# Out:
# *****
# *****
# *****
# *****

# %%
rows = 5
for i in range(1,rows + 1):
    print(" " * (rows - i)+ "*" * " " * (2* i -3))
